# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import/mount
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#local audio file request 1
import requests
filename = "/content/drive/MyDrive/Automated Debate Scoring/data/eds01.mp3"
def read_file(filename, chunk_size=5242880):
    with open(filename, 'rb') as _file:
        while True:
            data = _file.read(chunk_size)
            if not data:
                break
            yield data
json = {"speaker_labels": True}
headers = {'authorization': "f330e85d644243cd8c2b8506b312c55d"}
response = requests.post('https://api.assemblyai.com/v2/upload', json = json, headers=headers, data=read_file(filename))

print(response.json())
# Out:
# {'upload_url': 'https://cdn.assemblyai.com/upload/ed495e77-c44e-454a-9082-8a9e75aa4e94'}

# %%
#local audio file request 2
import requests
endpoint = "https://api.assemblyai.com/v2/transcript"
json = { "audio_url": "https://cdn.assemblyai.com/upload/e5041300-93e7-4391-8fff-270dc746703e" , "speaker_labels" : True}
headers = {
    "authorization": "f330e85d644243cd8c2b8506b312c55d",
    "content-type": "application/json"
}
response = requests.post(endpoint, json=json, headers=headers)
print(response.json())
# Out:
# {'id': 'ojky5g80qi-6ad8-4db9-a4d7-9eb2250f56be', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'language_code': 'en_us', 'status': 'queued', 'audio_url': 'https://cdn.assemblyai.com/upload/e5041300-93e7-4391-8fff-270dc746703e', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': False, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': True, 'content_safety': False, 'iab_categories': False, 'content_safety_labels': {}, 'iab_categories_result': {}, 'language_detection': False, 'custom_spelling': None, 'disfluencies': 
# ...

# %%
#local audio file return
import requests
endpoint = "https://api.assemblyai.com/v2/transcript/ouvw6m69gx-f666-4d39-8c02-be95b634b9e5"
headers = {
    "authorization": "f330e85d644243cd8c2b8506b312c55d",
}
response = requests.get(endpoint, headers=headers)
print(response.json())
# Out:
# {'id': 'ouvw6m69gx-f666-4d39-8c02-be95b634b9e5', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'language_code': 'en_us', 'status': 'completed', 'audio_url': 'https://cdn.assemblyai.com/upload/e5041300-93e7-4391-8fff-270dc746703e', 'text': "First of all, I would like to start off with the revolution from the government and then move on to our two main arguments. To start off with the revolution, we agree with the goal of preserving well being of the child. However, this well being does not not only need the physical wellbeing, but it also includes mental wellbeing. And in their side we can not protect the child's mental wellbeing as much as our as I can. And also regarding what the religious cases that they're talking about. Some religious might think that their religion belief and stuff like that is like the main value and things. But in our modern society, these kind of cases where they do degrees of those actions is actually considered as child abu
# ...

# %%
text_json = response.json()
text_json
# Out:
# {'acoustic_model': 'assemblyai_default',
#  'audio_duration': 2093,
#  'audio_end_at': None,
#  'audio_start_from': None,
#  'audio_url': 'https://cdn.assemblyai.com/upload/e5041300-93e7-4391-8fff-270dc746703e',
#  'auto_chapters': False,
#  'auto_highlights': False,
#  'auto_highlights_result': None,
#  'boost_param': None,
#  'chapters': None,
#  'confidence': 0.857938397932809,
#  'content_safety': False,
#  'content_safety_labels': {'results': [],
#   'status': 'unavailable',
#   'summary': {}},
#  'custom_spelling': None,
#  'disfluencies': False,
#  'dual_channel': None,
#  'entities': None,
#  'entity_detection': False,
#  'filter_profanity': False,
#  'format_text': True,
#  'iab_categories': False,
#  'iab_categories_result': {'results': [],
#   'status': 'unavailable',
#   'summary': {}},
#  'id': 'ouvw6m69gx-f666-4d39-8c02-be95b634b9e5',
#  'language_code': 'en_us',
#  'language_detection': False,
#  'language_model': 'assemblyai_default',
#  'punctuate': True,
# ...

# %%
text_json['text']
# Out:
# "First of all, I would like to start off with the revolution from the government and then move on to our two main arguments. To start off with the revolution, we agree with the goal of preserving well being of the child. However, this well being does not not only need the physical wellbeing, but it also includes mental wellbeing. And in their side we can not protect the child's mental wellbeing as much as our as I can. And also regarding what the religious cases that they're talking about. Some religious might think that their religion belief and stuff like that is like the main value and things. But in our modern society, these kind of cases where they do degrees of those actions is actually considered as child abuse. And in case of this is affecting their lives directly along with their life. And if they are actually killing people because of their religious belief of their parents, then we believe that this could be considered as child abuse cases and be treated legally so they ca
# ...

# %%
text_json['words']
# Out:
# [{'confidence': 0.96,
#   'end': 38794,
#   'speaker': 'A',
#   'start': 38630,
#   'text': 'First'},
#  {'confidence': 1.0,
#   'end': 38926,
#   'speaker': 'A',
#   'start': 38832,
#   'text': 'of'},
#  {'confidence': 0.95687,
#   'end': 39058,
#   'speaker': 'A',
#   'start': 38928,
#   'text': 'all,'},
#  {'confidence': 0.98,
#   'end': 39202,
#   'speaker': 'A',
#   'start': 39084,
#   'text': 'I'},
#  {'confidence': 0.97864,
#   'end': 39358,
#   'speaker': 'A',
#   'start': 39216,
#   'text': 'would'},
#  {'confidence': 0.99961,
#   'end': 39502,
#   'speaker': 'A',
#   'start': 39384,
#   'text': 'like'},
#  {'confidence': 1.0,
#   'end': 39622,
#   'speaker': 'A',
#   'start': 39516,
#   'text': 'to'},
#  {'confidence': 0.99447,
#   'end': 39778,
#   'speaker': 'A',
#   'start': 39636,
#   'text': 'start'},
#  {'confidence': 0.98317,
#   'end': 39958,
#   'speaker': 'A',
#   'start': 39804,
#   'text': 'off'},
#  {'confidence': 0.99,
#   'end': 40066,
#   'speaker': 'A',
# ...

# %%
len(text_json['words'])
# Out:
# 5035

# %%
text_json['words'][0]
# Out:
# {'confidence': 0.96,
#  'end': 38794,
#  'speaker': 'A',
#  'start': 38630,
#  'text': 'First'}

# %%
type(text_json)
# Out:
# dict

# %%
text_json['words'][0]['speaker']
# Out:
# 'A'

# %%
num_speakers=['N/A']

for i in range(len(text_json['words'])):
    if ([text_json['words'][i]['speaker']] not in num_speakers):
        num_speakers.append([text_json['words'][i]['speaker']])
        
print(num_speakers)
print(len(num_speakers))
# Out:
# ['N/A', ['A'], ['B'], ['C'], ['UNK'], ['D']]
# 6

# %%
num_speakers.remove('N/A')
print(num_speakers)
print(len(num_speakers))
# Out:
# [['A'], ['B'], ['C'], ['UNK'], ['D']]
# 5

# %%
num_speakers[0]
# Out:
# ['A']

# %%
num_speakers.index([text_json['words'][1000]['speaker']])
# Out:
# 0

# %%
a = num_speakers.index([text_json['words'][1000]['speaker']])
num_speakers[a]
# Out:
# ['A']

# %%
len(text_json['words'])
# Out:
# 5035

# %%
text_json['words'][1000]['text']
# Out:
# 'information'

# %%
ns = []
for i in range(len(num_speakers)):
    ns.append([i])
ns
# Out:
# [[0], [1], [2], [3], [4]]

# %%
for i in range(len(text_json['words'])):
    a = num_speakers.index([text_json['words'][i]['speaker']])
    #num_speakers[a].append(text_json['words'][i]['text'])
    ns[a] = ns[a] + [text_json['words'][i]['text']]

ns
# Out:
# [[0,
#   'First',
#   'of',
#   'all,',
#   'I',
#   'would',
#   'like',
#   'to',
#   'start',
#   'off',
#   'with',
#   'the',
#   'revolution',
#   'from',
#   'the',
#   'government',
#   'and',
#   'then',
#   'move',
#   'on',
#   'to',
#   'our',
#   'two',
#   'main',
#   'arguments.',
#   'To',
#   'start',
#   'off',
#   'with',
#   'the',
#   'revolution,',
#   'we',
#   'agree',
#   'with',
#   'the',
#   'goal',
#   'of',
#   'preserving',
#   'well',
#   'being',
#   'of',
#   'the',
#   'child.',
#   'However,',
#   'this',
#   'well',
#   'being',
#   'does',
#   'not',
#   'not',
#   'only',
#   'need',
#   'the',
#   'physical',
#   'wellbeing,',
#   'but',
#   'it',
#   'also',
#   'includes',
#   'mental',
#   'wellbeing.',
#   'And',
#   'in',
#   'their',
#   'side',
#   'we',
#   'can',
#   'not',
#   'protect',
#   'the',
#   "child's",
#   'mental',
#   'wellbeing',
#   'as',
#   'much',
#   'as',
#   'our',
#   'as',
#   'I',
#   'can.',
#   'And',
# ...

# %%
for i in range(len(ns)):
    ns[i].remove(i)
ns
# Out:
# [['First',
#   'of',
#   'all,',
#   'I',
#   'would',
#   'like',
#   'to',
#   'start',
#   'off',
#   'with',
#   'the',
#   'revolution',
#   'from',
#   'the',
#   'government',
#   'and',
#   'then',
#   'move',
#   'on',
#   'to',
#   'our',
#   'two',
#   'main',
#   'arguments.',
#   'To',
#   'start',
#   'off',
#   'with',
#   'the',
#   'revolution,',
#   'we',
#   'agree',
#   'with',
#   'the',
#   'goal',
#   'of',
#   'preserving',
#   'well',
#   'being',
#   'of',
#   'the',
#   'child.',
#   'However,',
#   'this',
#   'well',
#   'being',
#   'does',
#   'not',
#   'not',
#   'only',
#   'need',
#   'the',
#   'physical',
#   'wellbeing,',
#   'but',
#   'it',
#   'also',
#   'includes',
#   'mental',
#   'wellbeing.',
#   'And',
#   'in',
#   'their',
#   'side',
#   'we',
#   'can',
#   'not',
#   'protect',
#   'the',
#   "child's",
#   'mental',
#   'wellbeing',
#   'as',
#   'much',
#   'as',
#   'our',
#   'as',
#   'I',
#   'can.',
#   'And',
#   'also',
# ...

# %%
df = pd.DataFrame(ns)
new_df = df.T
new_df.columns = ['Speaker A', 'Speaker B', 'Speaker C', 'Speaker D', 'Speaker_E']
new_df
# Out:
#         Speaker A Speaker B   Speaker C Speaker D   Speaker_E
# 0           First       And    Boosting  Firstly.      Ladies
# 1              of     stuff          or  However.         and
# 2            all,      like  preserving     Okay?  gentlemen.
# 3               I     that.   wellbeing      None    Actually
# 4           would     Those          of      None       there
# ...           ...       ...         ...       ...         ...
# 1562  bargainship      None        None      None        None
# 1563      towards      None        None      None        None
# 1564        these      None        None      None        None
# 1565      medical      None        None      None        None
# 1566       cases.      None        None      None        None
#
# [1567 rows x 5 columns]

# %%
# !pip install brew
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 48 kB 3.7 MB/s
# WARNING: Discarding https://files.pythonhosted.org/packages/71/19/75f6d42ca862c6b31e2da9864d94f59fe81978ac5d40c43937a1c17fd065/brew-0.1.4.zip#sha256=11f23fe972631685e2a146f91747f78bbcad9dd2e20e6ea84a3058459c605948 (from https://pypi.org/simple/brew/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...
#      |████████████████████████████████| 42 kB 1.5 MB/s
# ...
#   Created wheel for brew: filename=brew-0.1.3-py2.py3-none-any.whl size=31438 sha256=365d5c739a96e67a69f19288aa86a1222faf76033aa7d1f6da9b167f898b9312
#   Stored in directory: /root/.cache/pip/wheels/8a/0a/23/a2e69280bbc6b4dfc90482bf8a43298dbaa77c0723da7d22f9
# Successfully built brew
# ...

# %%
# !pip install youtube-dl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 8.2 MB/s
# ...
